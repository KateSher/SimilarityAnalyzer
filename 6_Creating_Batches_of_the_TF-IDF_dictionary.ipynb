# %% [markdown]
# This notebook creates dictionaries for each keyword from a dictionary of unique words. The keywords are the keys of the dictionaries, and the values are the IDs of the documents (texts) and the weights of the corresponding documents.
#
# Creating dictionaries takes a lot of time, so it was decided to split them into 4 packages to speed up the work. To do this, you need to create 3 copies of this notebook. In each notebook, specify the corresponding slice of the dictionary (this is described below) and the corresponding folder for saving the batch.
#
# Dictionaries can be divided into any convenient number of batches, for this you need to create the appropriate number of copies of this notebook.

# %% [markdown]
# ## Loading the required libraries

# %%
import json

# %%
# Google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Reading tf-idf model with IDs of texts

# %%
tfidf_data_withID = []
for line in open('drive/MyDrive/Colab Notebooks/tfidf_data_withID.json', 'r'):
    tfidf_data_withID.append(json.loads(line))

# %%
print(tfidf_data_withID[:2])
# Out:
# [[['text0', 'anz', 0.0482463], ['text0', 'appearance', 0.0182636], ['text0', 'arch', 0.0301242], ['text0', 'australian', 0.0180499], ['text0', 'bankstown', 0.1825756], ['text0', 'beaten', 0.0292881], ['text0', 'born', 0.0080996], ['text0', 'brisbane', 0.1207643], ['text0', 'broncos', 0.2182702], ['text0', 'bulldogs', 0.107212], ['text0', 'canterbury', 0.2510069], ['text0', 'career', 0.0108858], ['text0', 'centre', 0.0163003], ['text0', 'children', 0.0134892], ['text0', 'club', 0.0280191], ['text0', 'com', 0.0168096], ['text0', 'contract', 0.0194018], ['text0', 'couple', 0.0218856], ['text0', 'cronulla', 0.0455894], ['text0', 'david', 0.0426766], ['text0', 'deal', 0.0387317], ['text0', 'debut', 0.0345433], ['text0', 'defeat', 0.0220487], ['text0', 'dropped', 0.0216048], ['text0', 'early', 0.0082615], ['text0', 'end', 0.0203032], ['text0', 'extended', 0.0195448], ['text0', 'external', 0.0030123], ['text0', 'fill', 0.0274206], ['text0', 'final', 0.0511782], ['text0', 'finished', 0.0181537], ['text0', 'football', 0.0160074], ['text0', 'footballer', 0.0231967], ['text0', 'game', 0.0302214], ['text0', 'games', 0.0464902], ['text0', 'girlfriend', 0.028987], ['text0', 'grand', 0.0538181], ['text0', 'high', 0.0096356], ['text0', 'injury', 0.0230953], ['text0', 'joining', 0.0232528], ['text0', 'junior', 0.0203667], ['text0', 'knee', 0.029372], ['text0', 'known', 0.0071017], ['text0', 'later', 0.0072443], ['text0', 'league', 0.0153894], ['text0', 'life', 0.0090968], ['text0', 'links', 0.0030195], ['text0', 'loss', 0.0195439], ['text0', 'married', 0.0148258], ['text0', 'melbourne', 0.0251695], ['text0', 'minor', 0.0194176], ['text0', 'new', 0.0051963], ['text0', 'norms', 0.0373977], ['text0', 'nrl', 0.4157932], ['text0', 'october', 0.0105842], ['text0', 'origin', 0.0421011], ['text0', 'parramatta', 0.042378], ['text0', 'personal', 0.014827], ['text0', 'play', 0.0139856], ['text0', 'played', 0.1077664], ['text0', 'preliminary', 0.0287452], ['text0', 'premiership', 0.0644991], ['text0', 'professional', 0.0152705], ['text0', 'profile', 0.0612448], ['text0', 'queensland', 0.0859622], ['text0', 'reached', 0.0172924], ['text0', 'record', 0.0283219], ['text0', 'regular', 0.0172786], ['text0', 'rejoined', 0.0321441], ['text0', 'representative', 0.0220661], ['text0', 'retiring', 0.0274113], ['text0', 'rivals', 0.0291724], ['text0', 'round', 0.0168248], ['text0', 'rounds', 0.0292094], ['text0', 'rugby', 0.0266799], ['text0', 'ruling', 0.0269279], ['text0', 'season', 0.1236753], ['text0', 'second', 0.0084408], ['text0', 'sellars', 0.0525662], ['text0', 'set', 0.0120927], ['text0', 'sharks', 0.0348278], ['text0', 'signed', 0.0169993], ['text0', 'stadium', 0.045211], ['text0', 'stagg', 0.7336756], ['text0', 'state', 0.0202057], ['text0', 'suffered', 0.0207655], ['text0', 'sutherland', 0.0341927], ['text0', 'table', 0.0217697], ['text0', 'tackles', 0.0734633], ['text0', 'tamika', 0.0568073], ['text0', 'telstra', 0.0466503], ['text0', 'townsville', 0.0429246], ['text0', 'trl', 0.0512476], ['text0', 'victory', 0.0198437], ['text0', 'winning', 0.0173896], ['text0', 'won', 0.0247549], ['text0', 'workload', 0.0428185], ['text0', 'year', 0.0214664], ['text0', 'fogs', 0.0590723], ['text0', 'references', 0.0010601]], [['text1', 'end', 0.015144], ['text1', 'external', 0.0014979], ['text1', 'high', 0.0047914], ['text1', 'known', 0.0035314], ['text1', 'later', 0.0036023], ['text1', 'links', 0.0015015], ['text1', 'new', 0.0103356], ['text1', 'set', 0.0060132], ['text1', 'state', 0.0552614], ['text1', 'accommodating', 0.0211387], ['text1', 'accommodations', 0.0204407], ['text1', 'accordingly', 0.0159007], ['text1', 'addiction', 0.0178402], ['text1', 'addition', 0.0147064], ['text1', 'admitting', 0.0188597], ['text1', 'alder', 0.0214347], ['text1', 'alternative', 0.0103492], ['text1', 'american', 0.0172197], ['text1', 'analysis', 0.0215761], ['text1', 'angles', 0.0172402], ['text1', 'angry', 0.0149843], ['text1', 'annual', 0.0089453], ['text1', 'archive', 0.0113498] ...

# %% [markdown]
# ## Reading a dictionary of keywords

# %%
with open('drive/MyDrive/Colab Notebooks/gensim_vocabulary.json', 'r') as f:
    basic_dict = json.load(f)

# %%
print(basic_dict)
# Out:
# {'0': 'anz', '1': 'appearance', '2': 'arch', '3': 'australian', '4': 'bankstown', '5': 'beaten', '6': 'born', '7': 'brisbane', '8': 'broncos', '9': 'bulldogs', '10': 'canterbury', '11': 'career', '12': 'centre', '13': 'children', '14': 'club', '15': 'com', '16': 'contract', '17': 'couple', '18': 'cronulla', '19': 'david', '20': 'deal', '21': 'debut', '22': 'defeat', '23': 'dropped', '24': 'early', '25': 'end', '26': 'extended', '27': 'external', '28': 'fill', '29': 'final', '30': 'finished', '31': 'football', '32': 'footballer', '33': 'game', '34': 'games', '35': 'girlfriend', '36': 'grand', '37': 'high', '38': 'injury', '39': 'joining', '40': 'junior', '41': 'knee', '42': 'known', '43': 'later', '44': 'league', '45': 'life', '46': 'links', '47': 'loss', '48': 'married', '49': 'melbourne', '50': 'minor', '51': 'new', '52': 'norms', '53': 'nrl', '54': 'october', '55': 'origin', '56': 'parramatta', '57': 'personal', '58': 'play', '59': 'played', '60': 'preliminary', '61': 'premiership', '62': 'professional', '63': 'profile', '64': 'queensland', '65': 'reached', '66': 'record', '67': 'regular', '68': 'rejoined', '69': 'representative', '70': 'retiring', '71': 'rivals', '72': 'round', '73': 'rounds', '74': 'rugby', '75': 'ruling', '76': 'season', '77': 'second', '78': 'sellars', '79': 'set', '80': 'sharks', '81': 'signed', '82': 'stadium', '83': 'stagg', '84': 'state', '85': 'suffered', '86': 'sutherland', '87': 'table', '88': 'tackles', '89': 'tamika', '90': 'telstra', '91': 'townsville', '92': 'trl', '93': 'victory', '94': 'winning', '95': 'won', '96': 'workload', '97': 'year', '98': 'accommodating', '99': 'accommodations', '100': 'accordingly', '101': 'addiction', '102': 'addition', '103': 'admitting', '104': 'alder', '105': 'alternative', '106': 'american', '107': 'analysis', '108': 'angles', '109': 'angry', '110': 'annual', '111': 'archive', '112': 'arrested', '113': 'arsonist', '114': 'articles', '115': 'association', '116': 'asylum', '117': 'attack', '118': 'attacked', '119': 'attendants', '120': 'bailey', '121': 'barbarous', '122': 'barn', '123': 'baskets', '124': 'bathing', '125': 'bed', '126': 'beds', '127': 'believed', '128': 'better', '129': 'blood', '130': 'bought', '131': 'brain', '132': 'brigham', '133': 'building', '134': 'buildings', '135': 'cages', '136': 'caldwell', '137': 'called', '138': 'calm', '139': 'campus', '140': 'captain', '141': 'care', '142': 'carpentry', '143': 'caught', '144': 'center', '145': 'central', '146': 'century', '147': 'certain', '148': 'chains', '149': 'chief', '150': 'christian', '151': 'clarissa', '152': 'clarke', '153': 'closed', '154': 'closets', '155': 'coffin', '156': 'colored', '157': 'columns', '158': 'commented', '159': 'compared', '160': 'completed', '161': 'construction', '162': 'contained', '163': 'contradicts', '164': 'contributions', '165': 'control', '166': 'convicted', '167': 'court', '168': 'courtyard', '169': 'crazy', '170': 'created', '171': 'creative', '172': 'crib', '173': 'cribs', '174': 'criticized', '175': 'curative', '176': 'current', '177': 'dated', '178': 'day', '179': 'days', '180': 'death', '181': 'deaths', '182': 'december', '183': 'decline', '184': 'decorate', '185': 'deep', '186': 'demolished', '187': 'demolition', '188': 'depth', '189': 'describes', '190': 'designed', '191': 'destroyed', '192': 'determine', '193': 'devoted', '194': 'diameter', '195': 'died', '196': 'dining', '197': 'director', '198': 'disliked', '199': 'display', '200': 'doctor', '201': 'doctors', '202': 'dormitories', '203': 'dr', '204': 'drawings', '205': 'east', '206': 'edinburgh', '207': 'editor', '208': 'editors', '209': 'employee', '210': 'encouraged', '211': 'english', '212': 'enlarged', '213': 'entire', '214': 'entrance', '215': 'essential', '216': 'evacuated', '217': 'excited', '218': 'facilities', '219': 'facility', '220': 'fact', '221': 'fair', '222': 'february', '223': 'fellows', '224': 'filled', '225': 'fire', '226': 'firefighter', '227': 'fires', '228': 'flesh', '229': 'floor ...

# %% [markdown]
# ## Specifying dictionary slices for each notebook copy
#
# To speed up data processing, you can run several copies of this notebook, processing one slice of data in each. Divided, for example, into 4 parts, as shown below for a dictionary of keywords consisting of 78844 words.
# In each copy of the notebook, specify the corresponding slice for the **slice_basic_dict** variable:
#
# 1.   [:19750]
# 2.   [19750:39500]
# 3.   [39500:59250]
# 4.   [59250:]

# %%
lst = list(basic_dict.items())
slice_basic_dict = dict(lst[:19750])
# print(slice_basic_dict)

# %% [markdown]
# ## Creating dictionaries
#
# Dictionaries were saved in 4 batches in folders for each of 4 notebook:
#
#
# 1.   temporary1
# 2.   temporary2
# 3.   temporary3
# 4.   temporary4

# %%
for k, v in slice_basic_dict.items():
    temp_dict = dict()
    with open('drive/MyDrive/Colab Notebooks/all_temporary/temporary1/%s.json' % k, 'w') as f:
        for text in tfidf_data_withID:
            for word in text:
                if v not in temp_dict:
                    temp_dict[v] = []
                if word[1] == v:
                    temp_dict[v].append([word[0], word[2]])
        json.dump(temp_dict, f, indent=4)
